# %%
import requests
import pandas as pd
from datetime import datetime

# %%
# Replace these variables with the owner and repository name of the repo you want to query
url = f"https://github.com/ebmdatalab/openprescribing/tree/main/openprescribing/measures/definitions/"

# Optionally, if you have a GitHub token, you can use it for authenticated requests to increase the rate limit
token = None  # Replace with your GitHub token or set to None if not using one

headers = {"Authorization": f"token {token}"} if token else {}

# %%
def fetch_commits(url, headers):
    commits = []
    while url:
        response = requests.get(url, headers=headers)
        
        # Debugging information
        print(f"Fetching: {url}")
        print(f"Status Code: {response.status_code}")
        
        if response.status_code == 200:
            try:
                data = response.json()
                commits.extend(data)
                # Check if there's a next page
                if 'next' in response.links:
                    url = response.links['next']['url']
                else:
                    url = None
            except json.JSONDecodeError as e:
                print(f"JSON Decode Error: {e}")
                print(f"Response content: {response.text}")
                break
        else:
            if response.status_code == 403:
                print("Rate limit exceeded. Try again later.")
            else:
                print(f"Error fetching commits: {response.status_code}")
                print(f"Response content: {response.text}")
            break
    return commits

commits = fetch_commits(url, headers)

# Extract useful information
commit_data = []
for commit in commits:
    commit_data.append({
        'sha': commit['sha'],
        'author': commit['commit']['author']['name'],
        'message': commit['commit']['message'],
        'date': datetime.strptime(commit['commit']['author']['date'], "%Y-%m-%dT%H:%M:%SZ")
    })

# Create a DataFrame
df = pd.DataFrame(commit_data)

# Display the first few rows of the DataFrame
df.head()
# Out:
# Fetching: https://github.com/ebmdatalab/openprescribing/tree/main/openprescribing/measures/definitions/
# Status Code: 200
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File /usr/local/lib/python3.12/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /usr/local/lib/python3.12/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File /usr/local/lib/python3.12/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File /usr/local/lib/python3.12/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 7 column 1 (char 6)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[9], line 12, in fetch_commits(url, headers)
#      11 try:
# ---> 12     data = response.json()
#      13     commits.extend(data)
#
# File /usr/local/lib/python3.12/site-packages/requests/models.py:975, in Response.json(self, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 7 column 1 (char 6)
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 32
#      29             break
#      30     return commits
# ---> 32 commits = fetch_commits(url, headers)
#      34 # Extract useful information
#      35 commit_data = []
#
# Cell In[9], line 19, in fetch_commits(url, headers)
#      17     else:
#      18         url = None
# ---> 19 except json.JSONDecodeError as e:
#      20     print(f"JSON Decode Error: {e}")
#      21     print(f"Response content: {response.text}")
#
# NameError: name 'json' is not defined

# %%
commits = fetch_commits(url, headers)

# Extract useful information
commit_data = []
for commit in commits:
    commit_data.append({
        'sha': commit['sha'],
        'author': commit['commit']['author']['name'],
        'message': commit['commit']['message'],
        'date': datetime.strptime(commit['commit']['author']['date'], "%Y-%m-%dT%H:%M:%SZ")
    })

# Create a DataFrame
df = pd.DataFrame(commit_data)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File /usr/local/lib/python3.12/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /usr/local/lib/python3.12/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File /usr/local/lib/python3.12/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File /usr/local/lib/python3.12/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 7 column 1 (char 6)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 commits = fetch_commits(url, headers)
#       3 # Extract useful information
#       4 commit_data = []
#
# Cell In[6], line 7, in fetch_commits(url, headers)
#       5 if response.status_code != 200:
#       6     raise Exception(f"Error fetching commits: {response.status_code}")
# ----> 7 data = response.json()
#       8 commits.extend(data)
#       9 # Check if there's a next page
#
# File /usr/local/lib/python3.12/site-packages/requests/models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 7 column 1 (char 6)

# %%
import requests
import pandas as pd
from datetime import datetime
import json

# Replace these variables with the owner and repository name of the repo you want to query
owner = "ebmdatalab"  # e.g., "octocat"
repo = "openprescribing"  # e.g., "Hello-World"
base_url = f"https://api.github.com/repos/{owner}/{repo}/pulls"

# Optionally, if you have a GitHub token, you can use it for authenticated requests to increase the rate limit
token = None  # Replace with your GitHub token or set to None if not using one

headers = {"Authorization": f"token {token}"} if token else {}

def fetch_pull_requests(url, state, headers):
    pull_requests = []
    page = 1
    
    while True:
        response = requests.get(f"{url}?state={state}&page={page}&per_page=100", headers=headers)
        
        # Debugging information
        print(f"Fetching: {url}?state={state}&page={page}&per_page=100")
        print(f"Status Code: {response.status_code}")
        
        if response.status_code == 200:
            try:
                data = response.json()
                if not data:
                    break
                pull_requests.extend(data)
                page += 1
            except json.JSONDecodeError as e:
                print(f"JSON Decode Error: {e}")
                print(f"Response content: {response.text}")
                break
        else:
            if response.status_code == 403:
                print("Rate limit exceeded. Try again later.")
            else:
                print(f"Error fetching pull requests: {response.status_code}")
                print(f"Response content: {response.text}")
            break
    return pull_requests

all_pull_requests = []

for state in ["open", "closed"]:
    print(f"Fetching {state} pull requests...")
    prs = fetch_pull_requests(base_url, state, headers)
    all_pull_requests.extend(prs)

# Extract useful information
pr_data = []
for pr in all_pull_requests:
    labels = [label['name'] for label in pr['labels']]
    pr_data.append({
        'id': pr['id'],
        'number': pr['number'],
        'title': pr['title'],
        'user': pr['user']['login'],
        'state': pr['state'],
        'created_at': datetime.strptime(pr['created_at'], "%Y-%m-%dT%H:%M:%SZ"),
        'updated_at': datetime.strptime(pr['updated_at'], "%Y-%m-%dT%H:%M:%SZ"),
        'closed_at': datetime.strptime(pr['closed_at'], "%Y-%m-%dT%H:%M:%SZ") if pr['closed_at'] else None,
        'merged_at': datetime.strptime(pr['merged_at'], "%Y-%m-%dT%H:%M:%SZ") if pr['merged_at'] else None,
        'branch': pr['head']['ref'],  # Branch name
        'labels': labels  # List of labels
    })

# Create a DataFrame
df = pd.DataFrame(pr_data)

# Display the first few rows of the DataFrame
df.head()
# Out:
# Fetching open pull requests...
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=open&page=1&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=open&page=2&per_page=100
# Status Code: 200
# Fetching closed pull requests...
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=1&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=2&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=3&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=4&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=5&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=6&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=7&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=8&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=9&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=10&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=11&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=12&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=13&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=14&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=15&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=16&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=17&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=18&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=19&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=20&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=21&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=22&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=23&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=24&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=25&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=26&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=27&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=28&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=29&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=30&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=31&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=32&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=33&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=34&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=35&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=36&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=37&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=38&per_page=100
# Status Code: 200
# Fetching: https://api.github.com/repos/ebmdatalab/openprescribing/pulls?state=closed&page=39&per_page=100
# Status Code: 200
#            id  number                                              title  \
# 0  1874548984    4793  chore(deps): bump google-cloud-bigquery from 3...
# 1  1874547523    4792   chore(deps): bump selenium from 4.20.0 to 4.21.0
# 2  1874545856    4791       chore(deps): bump trio from 0.25.0 to 0.25.1
# 3  1834510671    4757                             Amend measure  icsdose
# 4  1834400960    4756            Amend measure  ktt9 cephalosporins star
#
#               user state          created_at          updated_at closed_at  \
# 0  dependabot[bot]  open 2024-05-17 00:54:38 2024-05-17 00:54:39       NaT
# 1  dependabot[bot]  open 2024-05-17 00:52:07 2024-05-17 00:52:08       NaT
# 2  dependabot[bot]  open 2024-05-17 00:49:29 2024-05-17 00:49:30       NaT
# 3     chrisjwood16  open 2024-04-22 12:39:20 2024-04-30 10:42:44       NaT
# 4     chrisjwood16  open 2024-04-22 11:38:33 2024-04-22 11:38:33       NaT
#
#   merged_at                                       branch  \
# 0       NaT  dependabot/pip/google-cloud-bigquery-3.23.0
# 1       NaT               dependabot/pip/selenium-4.21.0
# 2       NaT                   dependabot/pip/trio-0.25.1
# 3       NaT                       amend_measure__icsdose
# 4       NaT      amend_measure__ktt9_cephalosporins_star
#
#                    labels
# 0  [dependencies, python]
# 1  [dependencies, python]
# 2  [dependencies, python]
# 3                      []
# 4                      []

# %%
# Filter the DataFrame by branch name and state
filtered_df = df[(df['branch'].str.startswith("new_measure")) & 
                 (df['state'] == 'closed') & 
                 (df['merged_at'].notna())]


# Display the filtered DataFrame
print(filtered_df)
# Out:
#              id  number                                              title  \
# 196  1699822579    4602  New measure fluoroquinolone items per 1000 reg...
# 464  1512199744    4314                        New measure  doxy 100 6 qty
# 637  1399512952    4129                             Create pregabalin.json
# 688  1360842021    4078                       new_measure__nhse_lancets_v2
# 702  1350708151    4063                             new_measure__nhse_bgts
# 759  1301563725    4000                 new_measure__amox_500_15_caps.json
#
#              user   state          created_at          updated_at  \
# 196  chrisjwood16  closed 2024-01-29 12:02:05 2024-02-20 19:33:13
# 464  richiecroker  closed 2023-09-12 14:02:53 2023-09-12 14:28:45
# 637  richiecroker  closed 2023-06-20 09:21:53 2023-06-20 09:35:31
# 688  richiecroker  closed 2023-05-23 07:43:11 2023-05-23 07:54:10
# 702  richiecroker  closed 2023-05-15 12:23:47 2023-05-22 22:18:51
# 759  richiecroker  closed 2023-04-04 12:09:54 2023-06-06 11:24:49
#
#               closed_at           merged_at  \
# 196 2024-02-20 19:33:12 2024-02-20 19:33:12
# 464 2023-09-12 14:28:44 2023-09-12 14:28:44
# 637 2023-06-20 09:35:30 2023-06-20 09:35:30
# 688 2023-05-23 07:54:09 2023-05-23 07:54:09
# 702 2023-05-22 22:18:50 2023-05-22 22:18:50
# 759 2023-06-06 11:24:48 2023-06-06 11:24:48
#
#                                  branch         labels
# 196  new_measure__fluoroquinolones_list             []
# 464         new_measure__doxy_100_6_qty  [New Measure]
# 637             new_measure__pregabalin             []
# 688         new_measure_nhse_lancets_v2             []
# 702              new_measure__nhse_bgts             []
# 759       new_measure__amox_500_15_caps  [New Measure]

# %%
print(df)
# Out:
#               id  number                                              title  \
# 0     1874548984    4793  chore(deps): bump google-cloud-bigquery from 3...
# 1     1874547523    4792   chore(deps): bump selenium from 4.20.0 to 4.21.0
# 2     1874545856    4791       chore(deps): bump trio from 0.25.0 to 0.25.1
# 3     1834510671    4757                             Amend measure  icsdose
# 4     1834400960    4756            Amend measure  ktt9 cephalosporins star
# ...          ...     ...                                                ...
# 3725    70672114      20                            Make failing tests pass
# 3726    70374906      17                                  Dockerise the app
# 3727    70190326      14           Update Travis notification email address
# 3728    70179374      12         Move the explanatory video below the fold.
# 3729    70178339      11               Minor documentation fixes and hints.
#
#                  user   state          created_at          updated_at  \
# 0     dependabot[bot]    open 2024-05-17 00:54:38 2024-05-17 00:54:39
# 1     dependabot[bot]    open 2024-05-17 00:52:07 2024-05-17 00:52:08
# 2     dependabot[bot]    open 2024-05-17 00:49:29 2024-05-17 00:49:30
# 3        chrisjwood16    open 2024-04-22 12:39:20 2024-04-30 10:42:44
# 4        chrisjwood16    open 2024-04-22 11:38:33 2024-04-22 11:38:33
# ...               ...     ...                 ...                 ...
# 3725         sebbacon  closed 2016-05-19 10:41:04 2016-06-14 13:10:19
# 3726         sebbacon  closed 2016-05-17 15:12:04 2016-06-14 13:10:15
# 3727  annapowellsmith  closed 2016-05-16 12:35:54 2016-05-17 09:29:20
# 3728         sebbacon  closed 2016-05-16 10:46:00 2016-05-23 18:49:23
# 3729         sebbacon  closed 2016-05-16 10:36:11 2016-06-14 13:10:18
#
#                closed_at           merged_at  \
# 0                    NaT                 NaT
# 1                    NaT                 NaT
# 2                    NaT                 NaT
# 3                    NaT                 NaT
# 4                    NaT                 NaT
# ...                  ...                 ...
# 3725 2016-05-19 10:58:37 2016-05-19 10:58:37
# 3726 2016-05-19 10:47:07 2016-05-19 10:47:07
# 3727 2016-05-17 09:29:18 2016-05-17 09:29:18
# 3728 2016-05-16 11:18:10 2016-05-16 11:18:10
# 3729 2016-05-16 10:49:11 2016-05-16 10:49:11
#
#                                            branch                  labels
# 0     dependabot/pip/google-cloud-bigquery-3.23.0  [dependencies, python]
# 1                  dependabot/pip/selenium-4.21.0  [dependencies, python]
# 2                      dependabot/pip/trio-0.25.1  [dependencies, python]
# 3                          amend_measure__icsdose                      []
# 4         amend_measure__ktt9_cephalosporins_star                      []
# ...                                           ...                     ...
# 3725                   fix-failing-filename-tests                      []
# 3726                                    dockerise                      []
# 3727           update-travis-notification-address                      []
# 3728                   reposition-home-page-video                      []
# 3729                           tweak-install-docs                      []
#
# [3730 rows x 11 columns]
